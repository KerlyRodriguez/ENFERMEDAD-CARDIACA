# %% [markdown]
# <a href="https://colab.research.google.com/github/KerlyRodriguez/ENFERMEDAD-CARDIACA/blob/main/Enf-cardiad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Predicción de Enfermedades Cardiacas con RBC**
#
# UNIVERSIDAD POLITÉCNICA SALESIANA
#
# INGENIERÍA EN SISTEMAS
#
# KERLY RODRIGUEZ LÓPEZ

# %% [markdown]
# **Planteamiento del Problema**
#
# En la actualidad las empresas están intentando implementar nuevos metodos para la deteccion de enfermededas como las cardiovasculares (ECV) ya que  cobra 17,9 millones de vidas cada año a nivel mundial, representando el 31% de todas las muertes en todo el mundo. Las personas que padecen enfermedades cardiovasculares o que tienen un alto riesgo cardiovascular por la presencia de multiples factores  como hipertensión, diabetes, hiperlipidemia o enfermedad ya establecida,  necesitan una detección y un manejo temprano, un modelo de aprendizaje automático es de gran ayuda ya que se intenta resolver un problema  por otro problema con ayuda de la IA

# %% [markdown]
# **Interpretación del DATASET**

# %% [markdown]
# **age** Edad
#
# **sex** Sexo
#
# **chest pain type** (4 values): Tipo del Dolor de Pecho TA:Angina Típica ATA: Angina Atípica NAP: Dolor no Anginal  ASY: Asintomático
#
# **resting blood pressure** Presión Arterial en reposo
#
# **serum cholestoral** Colesterol mg/dl
#
# **fasting blood sugar** Glucemia en ayunas (1 > 120 mg/dl 0< 120 mg/dl )
#
# **resting electrocardiographic results** Resultados de Electrocardiograma (values 0,1,2)
#
# **maximum heart rate achieved** Frecuencia maxima alcanzada
#
# **exercise induced angina** Angina inducido por el ejercicio
#
# **oldpeak** = Depresion del ST en relacion al ejericio
#
# The names and social security numbers of the patients were recently removed from the database, replaced with dummy values.

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import files

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv('/content/drive/MyDrive/insuficiencia cardiaca/Copia de heart.csv')
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
def sano_enfermo(fila):
    result = 'enfermo'
    if int(fila['target']) == 0:
        result = 'sano'
    return result

df['estado'] = df.apply(sano_enfermo, axis=1)
df.head(20)
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    52    1   0       125   212    0        1      168      0      1.0
# 1    53    1   0       140   203    1        0      155      1      3.1
# 2    70    1   0       145   174    0        1      125      1      2.6
# 3    61    1   0       148   203    0        1      161      0      0.0
# 4    62    0   0       138   294    1        1      106      0      1.9
# 5    58    0   0       100   248    0        0      122      0      1.0
# 6    58    1   0       114   318    0        2      140      0      4.4
# 7    55    1   0       160   289    0        0      145      1      0.8
# 8    46    1   0       120   249    0        0      144      0      0.8
# 9    54    1   0       122   286    0        0      116      1      3.2
# 10   71    0   0       112   149    0        1      125      0      1.6
# 11   43    0   0       132   341    1        0      136      1      3.0
# ...

# %%
resultado = dict(zip(df['target'].unique(), df['estado'].unique()))
resultado
# Out:
# {0: 'sano', 1: 'enfermo'}

# %%
from sklearn.model_selection import train_test_split

# %%
X = df[['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal']]
y = df['target']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, test_size=0.20)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
estimacion = knn.score(X_test, y_test)
print('La efectividad con el modelo de kNN es de {estimacion}')
# Out:
# La efectividad con el modelo de kNN es de {estimacion}

# %%
estimacion_prueba = knn.score(X_test, y_test)
estimacion_entrenamiento = knn.score(X_train, y_train)
print(f'La efectividad con la data de prueba con el modelo de kNN es de {estimacion_prueba}')
# Out:
# La efectividad con la data de prueba con el modelo de kNN es de 0.9121951219512195

# %%
df.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
# 5   58    0   0       100   248    0        0      122      0      1.0      1
# 6   58    1   0       114   318    0        2      140      0      4.4      0
# 7   55    1   0       160   289    0        0      145      1      0.8      1
# 8   46    1   0       120   249    0        0      144      0      0.8      2
# 9   54    1   0       122   286    0        0      116      1      3.2      1
#
#    ca  thal  target   estado
# 0   2     3       0     sano
# 1   0     3       0     sano
# ...

# %%
prediccion = knn.predict([[80, 0, 0, 120, 110, 0, 0, 110, 0, 1.0, 1, 0, 1]])
resultado[prediccion[0]]
# Out:
# 'sano'
